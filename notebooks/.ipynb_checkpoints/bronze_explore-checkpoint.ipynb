# %%
import pandas as pd
import trino
import json

# Cấu hình để Pandas hiển thị đầy đủ nội dung (quan trọng khi xem JSON)
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_colwidth', None)

print("Các thư viện đã sẵn sàng.")
# Out:
# Các thư viện đã sẵn sàng.

# %%
# Kết nối tới Trino service
conn = trino.dbapi.connect(
    host='localhost',
    port=8080,
    user='python-client', # Tên user bất kỳ
    catalog='lakehouse', # Tên catalog Iceberg bạn định nghĩa trong Flink
    schema='rva'         # Tên database bạn định nghĩa trong Flink
)

cursor = conn.cursor()
print(f"Kết nối Trino (Catalog: {conn.catalog}, Schema: {conn.schema}) thành công!")
# Out:
# Kết nối Trino (Catalog: lakehouse, Schema: rva) thành công!

# %%
cursor.execute("SHOW TABLES")
tables = cursor.fetchall()
print("Các bảng có trong schema 'rva':")
print(tables)

# Kết quả mong đợi: [('bronze_raw',)]
# Out:
# Các bảng có trong schema 'rva':
# [['bronze_raw']]

# %%
# Xem schema của bảng bronze_raw
df_schema = pd.read_sql("DESCRIBE bronze_raw", conn)
df_schema
# Out:
# /tmp/ipykernel_58481/1661251802.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_schema = pd.read_sql("DESCRIBE bronze_raw", conn)
#             Column                         Type Extra Comment
# 0   schema_version                      varchar
# 1  pipeline_run_id                      varchar
# 2      frame_index                       bigint
# 3          payload                      varchar
# 4        camera_id                      varchar
# 5         store_id                      varchar
# 6        ingest_ts  timestamp(6) with time zone

# %%
# Đếm tổng số dòng (records) trong bảng
# Con số này sẽ tăng lên nếu Flink job của bạn vẫn đang chạy
cursor.execute("SELECT COUNT(*) FROM bronze_raw")
total_rows = cursor.fetchone()[0]

print(f"Tổng số dòng (records) trong bảng 'bronze_raw': {total_rows}")
# Out:
# Tổng số dòng (records) trong bảng 'bronze_raw': 410

# %%
# Tìm ingest_ts (thời gian ghi dữ liệu) cũ nhất và mới nhất
df_time_range = pd.read_sql("""
    SELECT 
        MIN(ingest_ts) AS min_timestamp,
        MAX(ingest_ts) AS max_timestamp
    FROM bronze_raw
""", conn)

print("Phạm vi thời gian của dữ liệu:")
df_time_range
# Out:
# Phạm vi thời gian của dữ liệu:
# /tmp/ipykernel_58481/4236476250.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_time_range = pd.read_sql("""
#                      min_timestamp                    max_timestamp
# 0 2025-11-06 09:52:52.096000+00:00 2025-11-06 09:53:02.525000+00:00

# %%
# Đọc 5 dòng đầu tiên
df_sample = pd.read_sql("SELECT * FROM bronze_raw LIMIT 5", conn)
df_sample
# Out:
# /tmp/ipykernel_58481/3061181187.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_sample = pd.read_sql("SELECT * FROM bronze_raw LIMIT 5", conn)
#   schema_version                   pipeline_run_id  frame_index  \
# 0            1.0  27f0344f42da49558518258a3d50263c            1
# 1            1.0  27f0344f42da49558518258a3d50263c            2
# 2            1.0  27f0344f42da49558518258a3d50263c            3
# 3            1.0  27f0344f42da49558518258a3d50263c            4
# 4            1.0  27f0344f42da49558518258a3d50263c            5
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        payload  \
# 0  {"schema_version": "1.0", "pipeline_run_id": "27f0344f42da49558518258a3d50263c", "source": {"store_id": "store_01", "camera_id": "cam_01", "stream_id": "stream_01"}, "frame_index": 1, "capture_ts": "2025-10-31T13:22:36.674047+00:00", "image_size": {"width": 1280, "height": 720}, "detections": [{"det_id": "1-0", "class": null, "class_id": 0, "conf": 0.8199, "bbox": {"x1": 345.0, "y1": 58.0, "x2": 438.0, "y2": 430.0}, "bbox_norm": {"x": 0.26953125, "y": 0.08055555555555556, "w": 0.07265625, "h": 0.5166666666666667}, "centroid": {"x": 392, "y": 244}, "centroid_norm": {"x": 0.305859375, "y": 0.3388888888888889}, "track_id": null}]}
# 1       {"schema_version": "1.0", "pipeline_run_id": "27f0344f42da49558518258a3d50263c", "source": {"store_id": "store_01", "camera_id": "cam_01", "stream_id": "stream_01"}, "frame_index": 2, "capture_ts": "2025-10-31T13:22:36.712082+00:00", "image_size": {"width": 1280, "height": 720}, "detections": [{"det_id": "2-0", "class": null, "class_id": 0, "conf": 0.8254, "bbox": {"x1": 344.0, "y1": 58.0, "x2": 438.0, "y2": 430.0}, "bbox_norm": {"x": 0.26875, "y": 0.08055555555555556, "w": 0.0734375, "h": 0.5166666666666667}, "centroid": {"x": 391, "y": 244}, "centroid_norm": {"x": 0.30546875, "y": 0.3388888888888889}, "track_id": null}]}
# 2         {"schema_version": "1.0", "pipeline_run_id": "27f0344f42da49558518258a3d50263c", "source": {"store_id": "store_01", "camera_id": "cam_01", "stream_id": "stream_01"}, "frame_index": 3, "capture_ts": "2025-10-31T13:22:36.750969+00:00", "image_size": {"width": 1280, "height": 720}, "detections": [{"det_id": "3-0", "class": null, "class_id": 0, "conf": 0.8267, "bbox": {"x1": 344.0, "y1": 58.0, "x2": 438.0, "y2": 429.0}, "bbox_norm": {"x": 0.26875, "y": 0.08055555555555556, "w": 0.0734375, "h": 0.5152777777777777}, "centroid": {"x": 391, "y": 244}, "centroid_norm": {"x": 0.30546875, "y": 0.33819444444444446}, "track_id": 1}]}
# 3       {"schema_version": "1.0", "pipeline_run_id": "27f0344f42da49558518258a3d50263c", "source": {"store_id": "store_01", "camera_id": "cam_01", "stream_id": "stream_01"}, "frame_index": 4, "capture_ts": "2025-10-31T13:22:36.789379+00:00", "image_size": {"width": 1280, "height": 720}, "detections": [{"det_id": "4-0", "class": null, "class_id": 0, "conf": 0.8237, "bbox": {"x1": 344.0, "y1": 57.0, "x2": 437.0, "y2": 430.0}, "bbox_norm": {"x": 0.26875, "y": 0.07916666666666666, "w": 0.07265625, "h": 0.5180555555555556}, "centroid": {"x": 390, "y": 244}, "centroid_norm": {"x": 0.305078125, "y": 0.33819444444444446}, "track_id": 1}]}
# 4       {"schema_version": "1.0", "pipeline_run_id": "27f0344f42da49558518258a3d50263c", "source": {"store_id": "store_01", "camera_id": "cam_01", "stream_id": "stream_01"}, "frame_index": 5, "capture_ts": "2025-10-31T13:22:36.829484+00:00", "image_size": {"width": 1280, "height": 720}, "detections": [{"det_id": "5-0", "class": null, "class_id": 0, "conf": 0.8251, "bbox": {"x1": 344.0, "y1": 58.0, "x2": 437.0, "y2": 431.0}, "bbox_norm": {"x": 0.26875, "y": 0.08055555555555556, "w": 0.07265625, "h": 0.5180555555555556}, "centroid": {"x": 390, "y": 244}, "centroid_norm": {"x": 0.305078125, "y": 0.33958333333333335}, "track_id": 1}]}
#
#   camera_id  store_id                        ingest_ts
# 0    cam_01  store_01 2025-11-06 09:52:52.096000+00:00
# 1    cam_01  store_01 2025-11-06 09:52:52.494000+00:00
# 2    cam_01  store_01 2025-11-06 09:52:52.495000+00:00
# 3    cam_01  store_01 2025-11-06 09:52:52.496000+00:00
# 4    cam_01  store_01 2025-11-06 09:52:52.496000+00:00

# %%
# Lấy payload của 1 dòng
cursor.execute("SELECT payload FROM bronze_raw WHERE payload IS NOT NULL LIMIT 1")
result = cursor.fetchone()

if result:
    raw_payload_str = result[0]
    
    # Parse (phân tích) chuỗi JSON bằng Python
    payload_json = json.loads(raw_payload_str)
    
    # In ra cấu trúc JSON cho dễ đọc
    print("Cấu trúc của 1 dòng dữ liệu 'payload':")
    print(json.dumps(payload_json, indent=2, ensure_ascii=False))
else:
    print("Không tìm thấy dòng nào có payload. (Có thể job Flink chưa ghi dữ liệu?)")
# Out:
# Cấu trúc của 1 dòng dữ liệu 'payload':
# {
#   "schema_version": "1.0",
#   "pipeline_run_id": "27f0344f42da49558518258a3d50263c",
#   "source": {
#     "store_id": "store_01",
#     "camera_id": "cam_01",
#     "stream_id": "stream_01"
#   },
#   "frame_index": 1,
#   "capture_ts": "2025-10-31T13:22:36.674047+00:00",
#   "image_size": {
#     "width": 1280,
#     "height": 720
#   },
#   "detections": [
#     {
#       "det_id": "1-0",
#       "class": null,
#       "class_id": 0,
#       "conf": 0.8199,
#       "bbox": {
#         "x1": 345.0,
#         "y1": 58.0,
#         "x2": 438.0,
#         "y2": 430.0
#       },
#       "bbox_norm": {
#         "x": 0.26953125,
#         "y": 0.08055555555555556,
#         "w": 0.07265625,
#         "h": 0.5166666666666667
#       },
#       "centroid": {
#         "x": 392,
#         "y": 244
#       },
#       "centroid_norm": {
#         "x": 0.305859375,
#         "y": 0.3388888888888889
#       },
#       "track_id": null
#     }
#   ]
# }

# %%
# Đếm số dòng (records) theo store_id và camera_id
df_counts = pd.read_sql("""
    SELECT 
        store_id, 
        camera_id, 
        COUNT(*) AS total_records
    FROM bronze_raw
    GROUP BY 1, 2
    ORDER BY 3 DESC
""", conn)

print("Phân bố dữ liệu theo camera/store:")
df_counts
# Out:
# /tmp/ipykernel_58481/1412639990.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_counts = pd.read_sql("""
# Phân bố dữ liệu theo camera/store:
#    store_id camera_id  total_records
# 0  store_01    cam_01            410

# %%
# !pip install sqlalchemy trino[sqlalchemy]
# Out:
# Collecting sqlalchemy
#   Downloading sqlalchemy-2.0.44-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.5 kB)
# Requirement already satisfied: trino[sqlalchemy] in /home/hungfnguyen/project/retail-video-analytics/.venv/lib/python3.12/site-packages (0.336.0)
# Collecting greenlet>=1 (from sqlalchemy)
#   Downloading greenlet-3.2.4-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (4.1 kB)
# Requirement already satisfied: typing-extensions>=4.6.0 in /home/hungfnguyen/project/retail-video-analytics/.venv/lib/python3.12/site-packages (from sqlalchemy) (4.15.0)
# Requirement already satisfied: lz4 in /home/hungfnguyen/project/retail-video-analytics/.venv/lib/python3.12/site-packages (from trino[sqlalchemy]) (4.4.5)
# Requirement already satisfied: orjson>=3.11.0 in /home/hungfnguyen/project/retail-video-analytics/.venv/lib/python3.12/site-packages (from trino[sqlalchemy]) (3.11.4)
# Requirement already satisfied: python-dateutil in /home/hungfnguyen/project/retail-video-analytics/.venv/lib/python3.12/site-packages (from trino[sqlalchemy]) (2.9.0.post0)
# Requirement already satisfied: pytz in /home/hungfnguyen/project/retail-video-analytics/.venv/lib/python3.12/site-packages (from trino[sqlalchemy]) (2025.2)
# Requirement already satisfied: requests>=2.32.4 in /home/hungfnguyen/project/retail-video-analytics/.venv/lib/python3.12/site-packages (from trino[sqlalchemy]) (2.32.5)
# Requirement already satisfied: tzlocal in /home/hungfnguyen/project/retail-video-analytics/.venv/lib/python3.12/site-packages (from trino[sqlalchemy]) (5.3.1)
# Requirement already satisfied: zstandard in /home/hungfnguyen/project/retail-video-analytics/.venv/lib/python3.12/site-packages (from trino[sqlalchemy]) (0.25.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/hungfnguyen/project/retail-video-analytics/.venv/lib/python3.12/site-packages (from requests>=2.32.4->trino[sqlalchemy]) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /home/hungfnguyen/project/retail-video-analytics/.venv/lib/python3.12/site-packages (from requests>=2.32.4->trino[sqlalchemy]) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/hungfnguyen/project/retail-video-analytics/.venv/lib/python3.12/site-packages (from requests>=2.32.4->trino[sqlalchemy]) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/hungfnguyen/project/retail-video-analytics/.venv/lib/python3.12/site-packages (from requests>=2.32.4->trino[sqlalchemy]) (2025.8.3)
# Requirement already satisfied: six>=1.5 in /home/hungfnguyen/project/retail-video-analytics/.venv/lib/python3.12/site-packages (from python-dateutil->trino[sqlalchemy]) (1.17.0)
# Downloading sqlalchemy-2.0.44-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 17.4 MB/s  0:00:00.8 MB/s eta 0:00:01
# Downloading greenlet-3.2.4-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (607 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 607.6/607.6 kB 56.0 MB/s  0:00:00
# Installing collected packages: greenlet, sqlalchemy
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [sqlalchemy] 1/2 [sqlalchemy]
# Successfully installed greenlet-3.2.4 sqlalchemy-2.0.44
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
from sqlalchemy import create_engine
import pandas as pd

engine = create_engine("trino://python-client@localhost:8080/lakehouse/rva")

sql = """
SELECT record_count, file_size_in_bytes, file_path
FROM "bronze_raw$files"
ORDER BY file_size_in_bytes DESC
LIMIT 10
"""
df = pd.read_sql(sql, engine)
# Out:
# ---------------------------------------------------------------------------
# TrinoUserError                            Traceback (most recent call last)
# File ~/project/retail-video-analytics/.venv/lib/python3.12/site-packages/sqlalchemy/engine/base.py:1967, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1966     if not evt_handled:
# -> 1967         self.dialect.do_execute(
#    1968             cursor, str_statement, effective_parameters, context
#    1969         )
#    1971 if self._has_events or self.engine._has_events:
#
# File ~/project/retail-video-analytics/.venv/lib/python3.12/site-packages/trino/sqlalchemy/dialect.py:442, in TrinoDialect.do_execute(self, cursor, statement, parameters, context)
#     439 def do_execute(
#     440     self, cursor: Cursor, statement: str, parameters: Tuple[Any, ...], context: DefaultExecutionContext = None
#     441 ):
# --> 442     cursor.execute(statement, parameters)
#
# File ~/project/retail-video-analytics/.venv/lib/python3.12/site-packages/trino/dbapi.py:640, in Cursor.execute(self, operation, params)
#     638     self._query = trino.client.TrinoQuery(self._request, query=operation,
#     639                                           legacy_primitive_types=self._legacy_primitive_types)
# --> 640     self._iterator = iter(self._query.execute())
#     641 return self
#
# File ~/project/retail-video-analytics/.venv/lib/python3.12/site-packages/trino/client.py:909, in TrinoQuery.execute(self, additional_http_headers)
#     908 while not self.finished and not self.cancelled and len(self._result.rows) == 0:
# --> 909     self._result.rows += self.fetch()
#     910 return self._result
#
# File ~/project/retail-video-analytics/.venv/lib/python3.12/site-packages/trino/client.py:929, in TrinoQuery.fetch(self)
#     928     raise trino.exceptions.TrinoConnectionError("failed to fetch: {}".format(e))
# --> 929 status = self._request.process(response)
#     930 self._update_state(status)
#
# File ~/project/retail-video-analytics/.venv/lib/python3.12/site-packages/trino/client.py:698, in TrinoRequest.process(self, http_response)
#     697 if "error" in response and response["error"]:
# --> 698     raise self._process_error(response["error"], response.get("id"))
#     700 if constants.HEADER_CLEAR_SESSION in http_response.headers:
#
# TrinoUserError: TrinoUserError(type=USER_ERROR, name=SYNTAX_ERROR, message="line 3:16: mismatched input '$'. Expecting: ',', '.', 'AS', 'CROSS', 'EXCEPT', 'FETCH', 'FOR', 'FULL', 'GROUP', 'HAVING', 'INNER', 'INTERSECT', 'JOIN', 'LEFT', 'LIMIT', 'MATCH_RECOGNIZE', 'NATURAL', 'OFFSET', 'ORDER', 'RIGHT', 'TABLESAMPLE', 'UNION', 'WHERE', 'WINDOW', <EOF>, <identifier>", query_id=20251108_163331_00002_yaimv)
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# Cell In[2], line 12
#       4 engine = create_engine("trino://python-client@localhost:8080/lakehouse/rva")
#       6 sql = """
#       7 SELECT record_count, file_size_in_bytes, file_path
#       8 FROM bronze_raw$files
#       9 ORDER BY file_size_in_bytes DESC
#      10 LIMIT 10
#      11 """
# ---> 12 df = pd.read_sql(sql, engine)
#      13 df
#
# File ~/project/retail-video-analytics/.venv/lib/python3.12/site-packages/pandas/io/sql.py:736, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
#     726     return pandas_sql.read_table(
#     727         sql,
#     728         index_col=index_col,
#    (...)    733         dtype_backend=dtype_backend,
#     734     )
#     735 else:
# --> 736     return pandas_sql.read_query(
#     737         sql,
#     738         index_col=index_col,
#     739         params=params,
#     740         coerce_float=coerce_float,
#     741         parse_dates=parse_dates,
#     742         chunksize=chunksize,
#     743         dtype_backend=dtype_backend,
#     744         dtype=dtype,
#     745     )
#
# File ~/project/retail-video-analytics/.venv/lib/python3.12/site-packages/pandas/io/sql.py:1848, in SQLDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    1791 def read_query(
#    1792     self,
#    1793     sql: str,
#    (...)   1800     dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    1801 ) -> DataFrame | Iterator[DataFrame]:
#    1802     """
#    1803     Read SQL query into a DataFrame.
#    1804
#    (...)   1846
#    1847     """
# -> 1848     result = self.execute(sql, params)
#    1849     columns = result.keys()
#    1851     if chunksize is not None:
#
# File ~/project/retail-video-analytics/.venv/lib/python3.12/site-packages/pandas/io/sql.py:1671, in SQLDatabase.execute(self, sql, params)
#    1669 args = [] if params is None else [params]
#    1670 if isinstance(sql, str):
# -> 1671     return self.con.exec_driver_sql(sql, *args)
#    1672 return self.con.execute(sql, *args)
#
# File ~/project/retail-video-analytics/.venv/lib/python3.12/site-packages/sqlalchemy/engine/base.py:1779, in Connection.exec_driver_sql(self, statement, parameters, execution_options)
#    1774 execution_options = self._execution_options.merge_with(
#    1775     execution_options
#    1776 )
#    1778 dialect = self.dialect
# -> 1779 ret = self._execute_context(
#    1780     dialect,
#    1781     dialect.execution_ctx_cls._init_statement,
#    1782     statement,
#    1783     None,
#    1784     execution_options,
#    1785     statement,
#    1786     distilled_parameters,
#    1787 )
#    1789 return ret
#
# File ~/project/retail-video-analytics/.venv/lib/python3.12/site-packages/sqlalchemy/engine/base.py:1846, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1844     return self._exec_insertmany_context(dialect, context)
#    1845 else:
# -> 1846     return self._exec_single_context(
#    1847         dialect, context, statement, parameters
#    1848     )
#
# File ~/project/retail-video-analytics/.venv/lib/python3.12/site-packages/sqlalchemy/engine/base.py:1986, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1983     result = context._setup_result_proxy()
#    1985 except BaseException as e:
# -> 1986     self._handle_dbapi_exception(
#    1987         e, str_statement, effective_parameters, cursor, context
#    1988     )
#    1990 return result
#
# File ~/project/retail-video-analytics/.venv/lib/python3.12/site-packages/sqlalchemy/engine/base.py:2355, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2353 elif should_wrap:
#    2354     assert sqlalchemy_exception is not None
# -> 2355     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2356 else:
#    2357     assert exc_info[1] is not None
#
# File ~/project/retail-video-analytics/.venv/lib/python3.12/site-packages/sqlalchemy/engine/base.py:1967, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1965                 break
#    1966     if not evt_handled:
# -> 1967         self.dialect.do_execute(
#    1968             cursor, str_statement, effective_parameters, context
#    1969         )
#    1971 if self._has_events or self.engine._has_events:
#    1972     self.dispatch.after_cursor_execute(
#    1973         self,
#    1974         cursor,
#    (...)   1978         context.executemany,
#    1979     )
#
# File ~/project/retail-video-analytics/.venv/lib/python3.12/site-packages/trino/sqlalchemy/dialect.py:442, in TrinoDialect.do_execute(self, cursor, statement, parameters, context)
#     439 def do_execute(
#     440     self, cursor: Cursor, statement: str, parameters: Tuple[Any, ...], context: DefaultExecutionContext = None
#     441 ):
# --> 442     cursor.execute(statement, parameters)
#
# File ~/project/retail-video-analytics/.venv/lib/python3.12/site-packages/trino/dbapi.py:640, in Cursor.execute(self, operation, params)
#     637 else:
#     638     self._query = trino.client.TrinoQuery(self._request, query=operation,
#     639                                           legacy_primitive_types=self._legacy_primitive_types)
# --> 640     self._iterator = iter(self._query.execute())
#     641 return self
#
# File ~/project/retail-video-analytics/.venv/lib/python3.12/site-packages/trino/client.py:909, in TrinoQuery.execute(self, additional_http_headers)
#     907 # Execute should block until at least one row is received or query is finished or cancelled
#     908 while not self.finished and not self.cancelled and len(self._result.rows) == 0:
# --> 909     self._result.rows += self.fetch()
#     910 return self._result
#
# File ~/project/retail-video-analytics/.venv/lib/python3.12/site-packages/trino/client.py:929, in TrinoQuery.fetch(self)
#     927 except requests.exceptions.RequestException as e:
#     928     raise trino.exceptions.TrinoConnectionError("failed to fetch: {}".format(e))
# --> 929 status = self._request.process(response)
#     930 self._update_state(status)
#     931 if status.next_uri is None:
#
# File ~/project/retail-video-analytics/.venv/lib/python3.12/site-packages/trino/client.py:698, in TrinoRequest.process(self, http_response)
#     696 response = json.loads(http_response.text)
#     697 if "error" in response and response["error"]:
# --> 698     raise self._process_error(response["error"], response.get("id"))
#     700 if constants.HEADER_CLEAR_SESSION in http_response.headers:
#     701     for prop in get_header_values(
#     702         http_response.headers, constants.HEADER_CLEAR_SESSION
#     703     ):
#
# ProgrammingError: (trino.exceptions.TrinoUserError) TrinoUserError(type=USER_ERROR, name=SYNTAX_ERROR, message="line 3:16: mismatched input '$'. Expecting: ',', '.', 'AS', 'CROSS', 'EXCEPT', 'FETCH', 'FOR', 'FULL', 'GROUP', 'HAVING', 'INNER', 'INTERSECT', 'JOIN', 'LEFT', 'LIMIT', 'MATCH_RECOGNIZE', 'NATURAL', 'OFFSET', 'ORDER', 'RIGHT', 'TABLESAMPLE', 'UNION', 'WHERE', 'WINDOW', <EOF>, <identifier>", query_id=20251108_163331_00002_yaimv)
# [SQL:
# SELECT record_count, file_size_in_bytes, file_path
# FROM bronze_raw$files
# ORDER BY file_size_in_bytes DESC
# LIMIT 10
# ]
# (Background on this error at: https://sqlalche.me/e/20/f405)
